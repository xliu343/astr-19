# %%
import numpy as np
import matplotlib.pyplot as plt
random_numbers = np.random.random(1000)
fig, ax = plt.subplots()
ax.hist(random_numbers, bins=100)
ax.set_xlabel("Random Number Value")
ax.set_ylabel("Count")
fig.savefig("uniform_random_histogram.pdf")
plt.show()
